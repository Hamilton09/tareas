# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamilton09/tareas/blob/main/estructura_de_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas HAS TWO DATA STRUCTURE
import pandas as pd
tmp=pd.Series(data=[100,200,300,400],index=['Carlos', 'Mario', 'Rosuta', 'Juan'])

# %%
()

# %%
print(tmp)
# Out:
# Carlos    100
# Mario     200
# Rosuta    300
# Juan      400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
#imprimir le salario de Mario
print(tmp['Mario'])
# Out:
# 200

# %%
print(tmp['Rosuta'])
# Out:
# 300

# %%
print(tmp[-2])
# Out:
# 300

# %%
#multipl. por 2
tmp*2
# Out:
# Carlos    200
# Mario     400
# Rosuta    600
# Juan      800
# dtype: int64

# %%
#dividir. por 2
tmp/2
# Out:
# Carlos     50.0
# Mario     100.0
# Rosuta    150.0
# Juan      200.0
# dtype: float64

# %%
#imprimir valores de Juan, Mario, Rosita (con doble corchete)
tmp[[1,2,3]]
# Out:
# Mario     200
# Rosuta    300
# Juan      400
# dtype: int64

# %%
#optener los índices //estrctuta de datos
tmp.index
# Out:
# Index(['Carlos', 'Mario', 'Rosuta', 'Juan'], dtype='object')

# %%
#contenedores de filas y columas
#--CREAR DICCIONARIOS
mi_diccionario = {'name': 'Ivan', 'age': 25, 'city': 'New York'}

# %%
#crear un cuadro de datos a partir de diccionarios, con ESTRUCTURA de datos en Séries.
aux={'one':pd.Series([1,2,3], index=['apple', 'ball', 'clok']),
    'two':pd.Series([10,20,30], index=['primeapple', 'watermelon', 'banana'])}

# %%
#imprimir los cuadros
aux
# Out:
# {'one': apple    1
#  ball     2
#  clok     3
#  dtype: int64,
#  'two': primeapple    10
#  watermelon    20
#  banana        30
#  dtype: int64}

# %%
df=pd.DataFrame(aux)

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# ball        2.0   NaN
# banana      NaN  30.0
# clok        3.0   NaN
# primeapple  NaN  10.0
# watermelon  NaN  20.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'banana', 'clok', 'primeapple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
#tabla de 6*3 de multiplicación
df['three']=df['one']*df['two']

# %%
df
# Out:
#             one   two  three
# apple       1.0   NaN    NaN
# ball        2.0   NaN    NaN
# banana      NaN  30.0    NaN
# clok        3.0   NaN    NaN
# primeapple  NaN  10.0    NaN
# watermelon  NaN  20.0    NaN

# %%
#tabla de 6*3 de suma
df['for']=df['one']+df['two']

# %%
df
# Out:
#             one   two  three  for
# apple       1.0   NaN    NaN  NaN
# ball        2.0   NaN    NaN  NaN
# banana      NaN  30.0    NaN  NaN
# clok        3.0   NaN    NaN  NaN
# primeapple  NaN  10.0    NaN  NaN
# watermelon  NaN  20.0    NaN  NaN

# %%
#filtro ¿Columna 1 es mayor que la Columna 2?
df['Filtro']=df['one']>2

# %%
df
# Out:
#             one   two  three  for  Filtro
# apple       1.0   NaN    NaN  NaN   False
# ball        2.0   NaN    NaN  NaN   False
# banana      NaN  30.0    NaN  NaN   False
# clok        3.0   NaN    NaN  NaN    True
# primeapple  NaN  10.0    NaN  NaN   False
# watermelon  NaN  20.0    NaN  NaN   False

# %%
#Eliminar la columna 'Three'
del df['three']

# %%
df
# Out:
#             one   two  for  Filtro
# apple       1.0   NaN  NaN   False
# ball        2.0   NaN  NaN   False
# banana      NaN  30.0  NaN   False
# clok        3.0   NaN  NaN    True
# primeapple  NaN  10.0  NaN   False
# watermelon  NaN  20.0  NaN   False

# %%
#Eliminar la columna 'Three'
del df['Filtro']

# %%
df
# Out:
#             one   two  for
# apple       1.0   NaN  NaN
# ball        2.0   NaN  NaN
# banana      NaN  30.0  NaN
# clok        3.0   NaN  NaN
# primeapple  NaN  10.0  NaN
# watermelon  NaN  20.0  NaN

# %%
# otra forma de Eliminar la columna 'for'
#df2=df.pop('for')

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# ball        2.0   NaN
# banana      NaN  30.0
# clok        3.0   NaN
# primeapple  NaN  10.0
# watermelon  NaN  20.0

# %%
#CASE STUDY

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
#VER filas y columnas
tags.shape
# Out:
# (465564, 4)

# %%
#VER filas y columnas
ratings.shape
# Out:
# (2000000, 4)

# %%
#VER filas y columnas
movies.shape
# Out:
# (27278, 3)

# %%
#ver los datos de la TABLA
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
#imprimir los 10 primeros datos
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
#imprimir los 80 primeros datos
print(tags['tag'][:80])
# Out:
# 0                             Mark Waters
# 1                               dark hero
# 2                               dark hero
# 3                           noir thriller
# 4                               dark hero
#                      ...
# 75                           Vince Vaughn
# 76                           Will Ferrell
# 77                        Funniest Movies
# 78                              hilarious
# 79    One of the worst movies of all time
# Name: tag, Length: 80, dtype: object

# %%
#mostra las primeras 10 muestras
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
#mostra las primeras 10 muestras
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
#mostra las últimas 10 muestras con --->'tail'
tags.tail(10)
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967
